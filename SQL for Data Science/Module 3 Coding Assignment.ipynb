# %% [markdown]
# ### Module 3 Coding Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime

# %matplotlib inline
sns.set_style('dark')
sns.set(font_scale=1.2)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

np.random.seed(0)
np.set_printoptions(suppress=True)

# %% [markdown]
# Retrieve all the records from the Employees table

# %%
track = pd.read_csv("Track.csv")

# %%
track
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %% [markdown]
# Using a subquery, find the names of all the tracks for the album "Californication

# %%
cali = track[track["Name"] == "Californication"]

# %%
cali
# Out:
#       TrackId             Name  AlbumId  MediaTypeId  GenreId  \
# 2395     2396  Californication      195            1        1
#
#                    Composer  Milliseconds     Bytes  UnitPrice
# 2395  Red Hot Chili Peppers        321671  10568999       0.99

# %% [markdown]
# Not found

# %% [markdown]
# Find the total number of invoices for each customer along with the customer's full name, city and email

# %%
customers = pd.read_csv("Customer.csv")

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
invoices = pd.read_csv("Invoice.csv")

# %%
invoices
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
new_df1 = pd.merge(left=customers, right=invoices, on="CustomerId", how="inner")

# %%
new_df1
# Out:
#      CustomerId FirstName    LastName  \
# 0             1      Luís   Gonçalves
# 1             1      Luís   Gonçalves
# 2             1      Luís   Gonçalves
# 3             1      Luís   Gonçalves
# 4             1      Luís   Gonçalves
# ..          ...       ...         ...
# 407          59      Puja  Srivastava
# 408          59      Puja  Srivastava
# 409          59      Puja  Srivastava
# 410          59      Puja  Srivastava
# 411          59      Puja  Srivastava
#
#                                               Company  \
# 0    Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1    Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2    Embraer - Empresa Brasileira de Aeronáutica S.A.
# 3    Embraer - Empresa Brasileira de Aeronáutica S.A.
# 4    Embraer - Empresa Brasileira de Aeronáutica S.A.
# ..                                                ...
# 407                                               NaN
# 408                                               NaN
# ...

# %% [markdown]
# Find the total number of invoices for each customer along with the customer's full name, city and email

# %%
new_df1.groupby("CustomerId")["FirstName",'LastName','City','Email'].sum()
# Out:
#                                                     FirstName  \
# CustomerId
# 1                                LuísLuísLuísLuísLuísLuísLuís
# 2                  LeonieLeonieLeonieLeonieLeonieLeonieLeonie
# 3           FrançoisFrançoisFrançoisFrançoisFrançoisFranço...
# 4                         BjørnBjørnBjørnBjørnBjørnBjørnBjørn
# 5           FrantišekFrantišekFrantišekFrantišekFrantišekF...
# 6                  HelenaHelenaHelenaHelenaHelenaHelenaHelena
# 7                  AstridAstridAstridAstridAstridAstridAstrid
# 8                                DaanDaanDaanDaanDaanDaanDaan
# 9                                KaraKaraKaraKaraKaraKaraKara
# 10          EduardoEduardoEduardoEduardoEduardoEduardoEduardo
# 11          AlexandreAlexandreAlexandreAlexandreAlexandreA...
# 12          RobertoRobertoRobertoRobertoRobertoRobertoRoberto
# 13          FernandaFernandaFernandaFernandaFernandaFernan...
# 14                               MarkMarkMarkMarkMarkMarkMark
# ...

# %%
new_df1.groupby("CustomerId")["FirstName",'LastName','City','Email'].count()
# Out:
#             FirstName  LastName  City  Email
# CustomerId
# 1                   7         7     7      7
# 2                   7         7     7      7
# 3                   7         7     7      7
# 4                   7         7     7      7
# 5                   7         7     7      7
# 6                   7         7     7      7
# 7                   7         7     7      7
# 8                   7         7     7      7
# 9                   7         7     7      7
# 10                  7         7     7      7
# 11                  7         7     7      7
# 12                  7         7     7      7
# 13                  7         7     7      7
# 14                  7         7     7      7
# 15                  7         7     7      7
# 16                  7         7     7      7
# 17                  7         7     7      7
# 18                  7         7     7      7
# 19                  7         7     7      7
# 20                  7         7     7      7
# ...

# %% [markdown]
# After running the query described above, what is the email address of the 5th person, František Wichterlová? Enter the answer below (feel free to copy and paste).

# %% [markdown]
# frantisekw@jetbrains.com

# %% [markdown]
# Retrieve the track name, album, artistID, and trackID for all the albums

# %%
track
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
artist = pd.read_csv("Artist.csv")

# %%
artist
# Out:
#      ArtistId                                               Name
# 0           1                                              AC/DC
# 1           2                                             Accept
# 2           3                                          Aerosmith
# 3           4                                  Alanis Morissette
# 4           5                                    Alice In Chains
# ..        ...                                                ...
# 270       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271       272                             Emerson String Quartet
# 272       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273       274                                      Nash Ensemble
# 274       275                              Philip Glass Ensemble
#
# [275 rows x 2 columns]

# %%
album = pd.read_csv("Album.csv")

# %%
album
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
albumartist = pd.merge(left=album, right=artist, on="ArtistId")

# %%
albumartist
# Out:
#      AlbumId                                              Title  ArtistId  \
# 0          1              For Those About To Rock We Salute You         1
# 1          4                                  Let There Be Rock         1
# 2          2                                  Balls to the Wall         2
# 3          3                                  Restless and Wild         2
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      342  Locatelli: Concertos for Violin, Strings and C...       271
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
#                                                   Name
# ...

# %%
new_df2 = pd.merge(left=track, right=albumartist, on="AlbumId")

# %%
new_df2
# Out:
#       TrackId                                             Name_x  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           6                              Put The Finger On You        1
# 2           7                                    Let's Get It Up        1
# 3           8                                   Inject The Venom        1
# 4           9                                         Snowballed        1
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                   Composer  \
# ...

# %% [markdown]
# What is the song title of trackID 12 from the "For Those About to Rock We Salute You" album? Enter the answer below

# %%
new_df2[new_df2["TrackId"] == 12]
# Out:
#    TrackId              Name_x  AlbumId  MediaTypeId  GenreId  \
# 7       12  Breaking The Rules        1            1        1
#
#                                     Composer  Milliseconds    Bytes  \
# 7  Angus Young, Malcolm Young, Brian Johnson        263288  8596840
#
#    UnitPrice                                  Title  ArtistId Name_y
# 7       0.99  For Those About To Rock We Salute You         1  AC/DC

# %% [markdown]
# Retrieve a list with the managers last name, and the last name of the employees who report to him or her.

# %%
employee = pd.read_csv("Employee.csv")

# %%
employee
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %% [markdown]
# After running the query described above, who are the reports for the manager named Mitchell (select all that apply)?

# %% [markdown]
# King and Callahan

# %%
new_df2
# Out:
#       TrackId                                             Name_x  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           6                              Put The Finger On You        1
# 2           7                                    Let's Get It Up        1
# 3           8                                   Inject The Venom        1
# 4           9                                         Snowballed        1
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                   Composer  \
# ...

# %%
new_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3503 entries, 0 to 3502
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TrackId       3503 non-null   int64
#  1   Name_x        3503 non-null   object
#  2   AlbumId       3503 non-null   int64
#  3   MediaTypeId   3503 non-null   int64
#  4   GenreId       3503 non-null   int64
#  5   Composer      2525 non-null   object
#  6   Milliseconds  3503 non-null   int64
#  7   Bytes         3503 non-null   int64
#  8   UnitPrice     3503 non-null   float64
#  9   Title         3503 non-null   object
#  10  ArtistId      3503 non-null   int64
#  11  Name_y        3503 non-null   object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 355.8+ KB

# %%
new_df2.groupby("ArtistId").count()
# Out:
#           TrackId  Name_x  AlbumId  MediaTypeId  GenreId  Composer  \
# ArtistId
# 1              18      18       18           18       18        18
# 2               4       4        4            4        4         3
# 3              15      15       15           15       15        15
# 4              13      13       13           13       13        13
# 5              12      12       12           12       12        12
# ...           ...     ...      ...          ...      ...       ...
# 271             1       1        1            1        1         1
# 272             1       1        1            1        1         1
# 273             1       1        1            1        1         1
# 274             1       1        1            1        1         1
# 275             1       1        1            1        1         1
#
#           Milliseconds  Bytes  UnitPrice  Title  Name_y
# ArtistId
# 1                   18     18         18     18      18
# ...

# %%
zeroalbums = pd.DataFrame(new_df2.groupby("ArtistId").count())

# %%
zeroalbums
# Out:
#           TrackId  Name_x  AlbumId  MediaTypeId  GenreId  Composer  \
# ArtistId
# 1              18      18       18           18       18        18
# 2               4       4        4            4        4         3
# 3              15      15       15           15       15        15
# 4              13      13       13           13       13        13
# 5              12      12       12           12       12        12
# ...           ...     ...      ...          ...      ...       ...
# 271             1       1        1            1        1         1
# 272             1       1        1            1        1         1
# 273             1       1        1            1        1         1
# 274             1       1        1            1        1         1
# 275             1       1        1            1        1         1
#
#           Milliseconds  Bytes  UnitPrice  Title  Name_y
# ArtistId
# 1                   18     18         18     18      18
# ...

# %%
zeroalbums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 1 to 275
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TrackId       204 non-null    int64
#  1   Name_x        204 non-null    int64
#  2   AlbumId       204 non-null    int64
#  3   MediaTypeId   204 non-null    int64
#  4   GenreId       204 non-null    int64
#  5   Composer      204 non-null    int64
#  6   Milliseconds  204 non-null    int64
#  7   Bytes         204 non-null    int64
#  8   UnitPrice     204 non-null    int64
#  9   Title         204 non-null    int64
#  10  Name_y        204 non-null    int64
# dtypes: int64(11)
# memory usage: 19.1 KB

# %% [markdown]
# After running the query described above, two of the records returned have the same last name. Enter that name below.

# %% [markdown]
# Use a UNION to create a list of all the employee's and customer's first names and last names ordered by the last name in descending order.

# %%
employee
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
new_df4 = pd.concat([employee,customers],axis=0)

# %%
new_df4
# Out:
#     EmployeeId    LastName FirstName                Title  ReportsTo  \
# 0          1.0       Adams    Andrew      General Manager        NaN
# 1          2.0     Edwards     Nancy        Sales Manager        1.0
# 2          3.0     Peacock      Jane  Sales Support Agent        2.0
# 3          4.0        Park  Margaret  Sales Support Agent        2.0
# 4          5.0     Johnson     Steve  Sales Support Agent        2.0
# ..         ...         ...       ...                  ...        ...
# 54         NaN      Taylor      Mark                  NaN        NaN
# 55         NaN   Gutiérrez     Diego                  NaN        NaN
# 56         NaN       Rojas      Luis                  NaN        NaN
# 57         NaN      Pareek     Manoj                  NaN        NaN
# 58         NaN  Srivastava      Puja                  NaN        NaN
#
#               BirthDate             HireDate              Address  \
# 0   1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW
# ...

# %% [markdown]
# After running the query described above, determine what is the last name of the 6th record? Enter it below. Remember to order things in descending order to be sure to get the correct answer.

# %%
new_df4.iloc[5]
# Out:
# EmployeeId                            6
# LastName                       Mitchell
# FirstName                       Michael
# Title                        IT Manager
# ReportsTo                             1
# BirthDate           1973-07-01 00:00:00
# HireDate            2003-10-17 00:00:00
# Address            5827 Bowness Road NW
# City                            Calgary
# State                                AB
# Country                          Canada
# PostalCode                      T3B 0C5
# Phone                 +1 (403) 246-9887
# Fax                   +1 (403) 246-9899
# Email           michael@chinookcorp.com
# CustomerId                          NaN
# Company                             NaN
# SupportRepId                        NaN
# Name: 5, dtype: object

# %% [markdown]
# See if there are any customers who have a different city listed in their billing city versus their customer city.

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
invoices
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
new_df5 = pd.merge(left=invoices,right=customers,on="CustomerId")

# %%
new_df5
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1           12           2  2009-02-11 00:00:00
# 2           67           2  2009-10-12 00:00:00
# 3          196           2  2011-05-19 00:00:00
# 4          219           2  2011-08-21 00:00:00
# ..         ...         ...                  ...
# 407        171          35  2011-01-17 00:00:00
# 408        223          35  2011-09-07 00:00:00
# 409        344          35  2013-02-28 00:00:00
# 410        355          35  2013-04-10 00:00:00
# 411        410          35  2013-12-09 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 2                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 3                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# ...

# %%
new_df6 = new_df5[["BillingCity","City"]]

# %%
new_df6
# Out:
#     BillingCity       City
# 0     Stuttgart  Stuttgart
# 1     Stuttgart  Stuttgart
# 2     Stuttgart  Stuttgart
# 3     Stuttgart  Stuttgart
# 4     Stuttgart  Stuttgart
# ..          ...        ...
# 407       Porto      Porto
# 408       Porto      Porto
# 409       Porto      Porto
# 410       Porto      Porto
# 411       Porto      Porto
#
# [412 rows x 2 columns]

# %%
new_df6.to_csv("comparebilling.csv",index=False)
