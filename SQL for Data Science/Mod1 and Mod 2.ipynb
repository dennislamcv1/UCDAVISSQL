# %% [markdown]
# ### Module 1 Coding Questions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime

# %matplotlib inline
sns.set_style('dark')
sns.set(font_scale=1.2)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

np.random.seed(0)
np.set_printoptions(suppress=True)

# %% [markdown]
# Retrieve all the records from the Employees table

# %%
df = pd.read_csv("Employee.csv")

# %%
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %% [markdown]
# What is Robert King's mailing address? Note: You will have to scroll to the right in order to see it.

# %% [markdown]
# 590 Columbia Boulevard West

# %% [markdown]
# Retrieve the FirstName, LastName, Birthdate, Address, City, and State from the Employees table

# %%
emp = df[['FirstName','LastName', 'BirthDate','Address', 'City', 'State']]

# %%
emp
# Out:
#   FirstName  LastName            BirthDate                      Address  \
# 0    Andrew     Adams  1962-02-18 00:00:00          11120 Jasper Ave NW
# 1     Nancy   Edwards  1958-12-08 00:00:00                 825 8 Ave SW
# 2      Jane   Peacock  1973-08-29 00:00:00                1111 6 Ave SW
# 3  Margaret      Park  1947-09-19 00:00:00             683 10 Street SW
# 4     Steve   Johnson  1965-03-03 00:00:00                 7727B 41 Ave
# 5   Michael  Mitchell  1973-07-01 00:00:00         5827 Bowness Road NW
# 6    Robert      King  1970-05-29 00:00:00  590 Columbia Boulevard West
# 7     Laura  Callahan  1968-01-09 00:00:00                  923 7 ST NW
#
#          City State
# 0    Edmonton    AB
# 1     Calgary    AB
# 2     Calgary    AB
# 3     Calgary    AB
# 4     Calgary    AB
# 5     Calgary    AB
# 6  Lethbridge    AB
# 7  Lethbridge    AB

# %% [markdown]
# Which of the employees listed below has a birthdate of 3-3-1965?

# %% [markdown]
# Steve Johnson

# %% [markdown]
# Retrieve all the columns from the Tracks table, but only return 20 rows

# %%
tracks = pd.read_csv('Track.csv')

# %%
tracks.head(20)
# Out:
#     TrackId                                     Name  AlbumId  MediaTypeId  \
# 0         1  For Those About To Rock (We Salute You)        1            1
# 1         2                        Balls to the Wall        2            2
# 2         3                          Fast As a Shark        3            2
# 3         4                        Restless and Wild        3            2
# 4         5                     Princess of the Dawn        3            2
# 5         6                    Put The Finger On You        1            1
# 6         7                          Let's Get It Up        1            1
# 7         8                         Inject The Venom        1            1
# 8         9                               Snowballed        1            1
# 9        10                               Evil Walks        1            1
# 10       11                                   C.O.D.        1            1
# ...

# %% [markdown]
# What is the runtime in milliseconds for the 5th track, entitled "Princess of the Dawn"?

# %% [markdown]
# 375418

# %% [markdown]
# ### Module 2 Coding Assignment

# %% [markdown]
# Find all the tracks that have a length of 5,000,000 milliseconds or more

# %%
trackslong = tracks[tracks['Milliseconds'] >= 5000000]

# %%
trackslong
# Out:
#       TrackId                     Name  AlbumId  MediaTypeId  GenreId  \
# 2819     2820   Occupation / Precipice      227            3       19
# 3223     3224  Through a Looking Glass      229            3       21
#
#      Composer  Milliseconds       Bytes  UnitPrice
# 2819      NaN       5286953  1054423946       1.99
# 3223      NaN       5088838  1059546140       1.99

# %% [markdown]
# How many tracks are returned?

# %% [markdown]
# 2

# %% [markdown]
# Find all the invoices whose total is between $5 and $15 dollars

# %%
invoice = pd.read_csv("Invoice.csv")

# %%
invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
invoicebetween = invoice[(invoice["Total"] >= 5.00) & (invoice["Total"] <= 15.00)]

# %%
invoicebetween
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# 9           10          46  2009-02-03 00:00:00
# 10          11          52  2009-02-06 00:00:00
# ..         ...         ...                  ...
# 401        402          50  2013-11-05 00:00:00
# 402        403          56  2013-11-08 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
#
#                                BillingAddress   BillingCity BillingState  \
# 2                             Grétrystraat 63      Brussels          NaN
# 3                              8210 111 ST NW      Edmonton           AB
# 4                             69 Salem Street        Boston           MA
# 9                            3 Chatham Street        Dublin       Dublin
# ...

# %% [markdown]
# While the query in this example is limited to 10 records, running the query correctly will indicate how many total records there are - enter that number below.

# %% [markdown]
# 168

# %% [markdown]
# Find all the customers from the following States: RJ, DF, AB, BC, CA, WA, NY.

# %%
customers = pd.read_csv("Customer.csv")

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
customers["State"].value_counts()
# Out:
# SP        3
# CA        3
# ON        2
# NS        1
# RM        1
# BC        1
# Dublin    1
# AB        1
# WA        1
# IL        1
# MB        1
# AZ        1
# NY        1
# DF        1
# FL        1
# RJ        1
# NSW       1
# TX        1
# VV        1
# NT        1
# NV        1
# MA        1
# WI        1
# QC        1
# UT        1
# Name: State, dtype: int64

# %%
customers[customers["State"] == 'RJ']
# Out:
#     CustomerId FirstName LastName Company           Address            City  \
# 11          12   Roberto  Almeida  Riotur  Praça Pio X, 119  Rio de Janeiro
#
#    State Country PostalCode               Phone                 Fax  \
# 11    RJ  Brazil  20040-020  +55 (21) 2271-7000  +55 (21) 2271-7070
#
#                             Email  SupportRepId
# 11  roberto.almeida@riotur.gov.br             3

# %%
customers[customers["State"] == 'DF']
# Out:
#     CustomerId FirstName LastName Company       Address      City State  \
# 12          13  Fernanda    Ramos     NaN  Qe 7 Bloco G  Brasília    DF
#
#    Country PostalCode               Phone                 Fax  \
# 12  Brazil  71020-677  +55 (61) 3363-5547  +55 (61) 3363-7855
#
#                        Email  SupportRepId
# 12  fernadaramos4@uol.com.br             4

# %%
customers[customers["State"] == 'AB']
# Out:
#     CustomerId FirstName LastName Company         Address      City State  \
# 13          14      Mark  Philips   Telus  8210 111 ST NW  Edmonton    AB
#
#    Country PostalCode              Phone                Fax  \
# 13  Canada    T6G 2C7  +1 (780) 434-4554  +1 (780) 434-5565
#
#                  Email  SupportRepId
# 13  mphilips12@shaw.ca             5

# %%
customers[customers["State"] == 'BC']
# Out:
#     CustomerId FirstName  LastName        Company              Address  \
# 14          15  Jennifer  Peterson  Rogers Canada  700 W Pender Street
#
#          City State Country PostalCode              Phone                Fax  \
# 14  Vancouver    BC  Canada    V6C 1G8  +1 (604) 688-2255  +1 (604) 688-8756
#
#                   Email  SupportRepId
# 14  jenniferp@rogers.ca             3

# %%
customers[customers["State"] == 'CA']
# Out:
#     CustomerId FirstName LastName      Company                    Address  \
# 15          16     Frank   Harris  Google Inc.  1600 Amphitheatre Parkway
# 18          19       Tim    Goyer   Apple Inc.            1 Infinite Loop
# 19          20       Dan   Miller          NaN       541 Del Medio Avenue
#
#              City State Country  PostalCode              Phone  \
# 15  Mountain View    CA     USA  94043-1351  +1 (650) 253-0000
# 18      Cupertino    CA     USA       95014  +1 (408) 996-1010
# 19  Mountain View    CA     USA   94040-111  +1 (650) 644-3358
#
#                   Fax                Email  SupportRepId
# 15  +1 (650) 253-0000   fharris@google.com             4
# 18  +1 (408) 996-1011     tgoyer@apple.com             3
# 19                NaN  dmiller@comcast.com             4

# %%
customers[customers["State"] == 'WA']
# Out:
#     CustomerId FirstName LastName                Company          Address  \
# 16          17      Jack    Smith  Microsoft Corporation  1 Microsoft Way
#
#        City State Country  PostalCode              Phone                Fax  \
# 16  Redmond    WA     USA  98052-8300  +1 (425) 882-8080  +1 (425) 882-8081
#
#                       Email  SupportRepId
# 16  jacksmith@microsoft.com             5

# %%
customers[customers["State"] == 'NY']
# Out:
#     CustomerId FirstName LastName Company       Address      City State  \
# 17          18  Michelle   Brooks     NaN  627 Broadway  New York    NY
#
#    Country  PostalCode              Phone                Fax  \
# 17     USA  10012-2612  +1 (212) 221-3546  +1 (212) 221-4679
#
#                 Email  SupportRepId
# 17  michelleb@aol.com             3

# %% [markdown]
# What company does Jack Smith work for?

# %% [markdown]
# Microsoft Corp

# %%
invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %% [markdown]
# Find all the invoices for customer 56 and 58 where the total was between $1.00 and $5.00

# %%
invoice[invoice["CustomerId"] == 56]
# Out:
#      InvoiceId  CustomerId          InvoiceDate      BillingAddress  \
# 118        119          56  2010-06-12 00:00:00  307 Macacha Güemes
# 141        142          56  2010-09-14 00:00:00  307 Macacha Güemes
# 163        164          56  2010-12-17 00:00:00  307 Macacha Güemes
# 215        216          56  2011-08-07 00:00:00  307 Macacha Güemes
# 336        337          56  2013-01-28 00:00:00  307 Macacha Güemes
# 347        348          56  2013-03-10 00:00:00  307 Macacha Güemes
# 402        403          56  2013-11-08 00:00:00  307 Macacha Güemes
#
#       BillingCity BillingState BillingCountry BillingPostalCode  Total
# 118  Buenos Aires          NaN      Argentina              1106   1.98
# 141  Buenos Aires          NaN      Argentina              1106   3.96
# 163  Buenos Aires          NaN      Argentina              1106   5.94
# 215  Buenos Aires          NaN      Argentina              1106   0.99
# ...

# %%
invoice[invoice["CustomerId"] == 58]
# Out:
#      InvoiceId  CustomerId          InvoiceDate       BillingAddress  \
# 119        120          58  2010-06-12 00:00:00  12,Community Centre
# 130        131          58  2010-07-23 00:00:00  12,Community Centre
# 185        186          58  2011-03-23 00:00:00  12,Community Centre
# 314        315          58  2012-10-27 00:00:00  12,Community Centre
# 337        338          58  2013-01-29 00:00:00  12,Community Centre
# 359        360          58  2013-05-03 00:00:00  12,Community Centre
# 411        412          58  2013-12-22 00:00:00  12,Community Centre
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total
# 119       Delhi          NaN          India            110017   1.98
# 130       Delhi          NaN          India            110017  13.86
# 185       Delhi          NaN          India            110017   8.91
# 314       Delhi          NaN          India            110017   1.98
# 337       Delhi          NaN          India            110017   3.96
# ...

# %% [markdown]
# What was the invoice date for invoice ID 315?

# %%
invoice[invoice["InvoiceId"] == 315]
# Out:
#      InvoiceId  CustomerId          InvoiceDate       BillingAddress  \
# 314        315          58  2012-10-27 00:00:00  12,Community Centre
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total
# 314       Delhi          NaN          India            110017   1.98

# %% [markdown]
# Find all the tracks whose name starts with 'All'.

# %%
tracks
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
tracks[tracks["Name"].str.contains("All")]
# Out:
#       TrackId                                               Name  AlbumId  \
# 37         38                                  All I Really Want        6
# 133       134                                        All For You       14
# 384       385                                           All Star       33
# 421       422                                      I Want It All       36
# 451       452                             Rock And Roll All Nite       37
# 802       803                                  Love Conquers All       64
# 1008     1009                                        All My Life       81
# 1010     1011                                        Have It All       81
# 1101     1102                       Doce De Carnaval (Candy All)       87
# 1528     1529                                Always Be All Right      123
# 1575     1576                             Rock And Roll All Nite      126
# 1607     1608                                        All My Love      130
# ...

# %% [markdown]
# While only 10 records are shown, the query will indicate how many total records there are for this query - enter that number below

# %%
tracks[tracks["Name"].str.contains("All")].count()
# Out:
# TrackId         39
# Name            39
# AlbumId         39
# MediaTypeId     39
# GenreId         39
# Composer        32
# Milliseconds    39
# Bytes           39
# UnitPrice       39
# dtype: int64

# %% [markdown]
# Find all the customer emails that start with "J" and are from gmail.com

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
customers[customers["Email"].str.contains("gmail.com")]
# Out:
#     CustomerId  FirstName  LastName Company                Address  \
# 2            3   François  Tremblay     NaN      1498 rue Bélanger
# 5            6     Helena      Holý     NaN          Rilská 3174/6
# 21          22    Heather   Leacock     NaN       120 S Orange Ave
# 23          24      Frank   Ralston     NaN  162 E Superior Street
# 27          28      Julia   Barnett     NaN            302 S 700 E
# 30          31     Martha      Silk     NaN  194A Chain Lake Drive
# 39          40  Dominique  Lefebvre     NaN         8, Rue Hanovre
# 52          53       Phil    Hughes     NaN           113 Lupus St
#
#               City State         Country PostalCode               Phone  Fax  \
# 2         Montréal    QC          Canada    H2G 1A7   +1 (514) 721-4711  NaN
# 5           Prague   NaN  Czech Republic      14300    +420 2 4177 0449  NaN
# 21         Orlando    FL             USA      32801   +1 (407) 999-7788  NaN
# ...

# %% [markdown]
# Enter the one email address returned (you will likely need to scroll to the right) below.

# %% [markdown]
# jubarnett@gmail.com

# %% [markdown]
# Find all the invoices from the billing city Brasília, Edmonton, and Vancouver and sort in descending order by invoice ID.

# %%
invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
brasilia = invoice[invoice["BillingCity"] == "Brasília"]

# %%
brasilia
# Out:
#      InvoiceId  CustomerId          InvoiceDate BillingAddress BillingCity  \
# 34          35          13  2009-06-05 00:00:00   Qe 7 Bloco G    Brasília
# 57          58          13  2009-09-07 00:00:00   Qe 7 Bloco G    Brasília
# 79          80          13  2009-12-10 00:00:00   Qe 7 Bloco G    Brasília
# 131        132          13  2010-07-31 00:00:00   Qe 7 Bloco G    Brasília
# 252        253          13  2012-01-22 00:00:00   Qe 7 Bloco G    Brasília
# 263        264          13  2012-03-03 00:00:00   Qe 7 Bloco G    Brasília
# 318        319          13  2012-11-01 00:00:00   Qe 7 Bloco G    Brasília
#
#     BillingState BillingCountry BillingPostalCode  Total
# 34            DF         Brazil         71020-677   1.98
# 57            DF         Brazil         71020-677   3.96
# 79            DF         Brazil         71020-677   5.94
# 131           DF         Brazil         71020-677   0.99
# 252           DF         Brazil         71020-677   1.98
# ...

# %%
edmonton = invoice[invoice["BillingCity"] == "Edmonton"]

# %%
edmonton
# Out:
#      InvoiceId  CustomerId          InvoiceDate  BillingAddress BillingCity  \
# 3            4          14  2009-01-06 00:00:00  8210 111 ST NW    Edmonton
# 132        133          14  2010-08-13 00:00:00  8210 111 ST NW    Edmonton
# 155        156          14  2010-11-15 00:00:00  8210 111 ST NW    Edmonton
# 177        178          14  2011-02-17 00:00:00  8210 111 ST NW    Edmonton
# 229        230          14  2011-10-08 00:00:00  8210 111 ST NW    Edmonton
# 350        351          14  2013-03-31 00:00:00  8210 111 ST NW    Edmonton
# 361        362          14  2013-05-11 00:00:00  8210 111 ST NW    Edmonton
#
#     BillingState BillingCountry BillingPostalCode  Total
# 3             AB         Canada           T6G 2C7   8.91
# 132           AB         Canada           T6G 2C7   1.98
# 155           AB         Canada           T6G 2C7   3.96
# 177           AB         Canada           T6G 2C7   5.94
# 229           AB         Canada           T6G 2C7   0.99
# ...

# %%
vancouver = invoice[invoice["BillingCity"] == "Vancouver"]

# %%
vancouver
# Out:
#      InvoiceId  CustomerId          InvoiceDate       BillingAddress  \
# 35          36          15  2009-06-05 00:00:00  700 W Pender Street
# 46          47          15  2009-07-16 00:00:00  700 W Pender Street
# 101        102          15  2010-03-16 00:00:00  700 W Pender Street
# 230        231          15  2011-10-21 00:00:00  700 W Pender Street
# 253        254          15  2012-01-23 00:00:00  700 W Pender Street
# 275        276          15  2012-04-26 00:00:00  700 W Pender Street
# 327        328          15  2012-12-15 00:00:00  700 W Pender Street
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total
# 35    Vancouver           BC         Canada           V6C 1G8   1.98
# 46    Vancouver           BC         Canada           V6C 1G8  13.86
# 101   Vancouver           BC         Canada           V6C 1G8   9.91
# 230   Vancouver           BC         Canada           V6C 1G8   1.98
# 253   Vancouver           BC         Canada           V6C 1G8   3.96
# ...

# %%
brasilia.sort_values(by="InvoiceId")
# Out:
#      InvoiceId  CustomerId          InvoiceDate BillingAddress BillingCity  \
# 34          35          13  2009-06-05 00:00:00   Qe 7 Bloco G    Brasília
# 57          58          13  2009-09-07 00:00:00   Qe 7 Bloco G    Brasília
# 79          80          13  2009-12-10 00:00:00   Qe 7 Bloco G    Brasília
# 131        132          13  2010-07-31 00:00:00   Qe 7 Bloco G    Brasília
# 252        253          13  2012-01-22 00:00:00   Qe 7 Bloco G    Brasília
# 263        264          13  2012-03-03 00:00:00   Qe 7 Bloco G    Brasília
# 318        319          13  2012-11-01 00:00:00   Qe 7 Bloco G    Brasília
#
#     BillingState BillingCountry BillingPostalCode  Total
# 34            DF         Brazil         71020-677   1.98
# 57            DF         Brazil         71020-677   3.96
# 79            DF         Brazil         71020-677   5.94
# 131           DF         Brazil         71020-677   0.99
# 252           DF         Brazil         71020-677   1.98
# ...

# %% [markdown]
# What is the total invoice amount of the first record returned? Enter the number below without a $ sign. Remember to sort in descending order to get the correct answer.

# %% [markdown]
# 1.98

# %% [markdown]
# Show the number of orders placed by each customer (hint: this is found in the invoices table) and sort the result by the number of orders in descending order.

# %%
invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
invoice.groupby("CustomerId").count()
# Out:
#             InvoiceId  InvoiceDate  BillingAddress  BillingCity  BillingState  \
# CustomerId
# 1                   7            7               7            7             7
# 2                   7            7               7            7             0
# 3                   7            7               7            7             7
# 4                   7            7               7            7             0
# 5                   7            7               7            7             0
# 6                   7            7               7            7             0
# 7                   7            7               7            7             0
# 8                   7            7               7            7             0
# 9                   7            7               7            7             0
# 10                  7            7               7            7             7
# 11                  7            7               7            7             7
# ...

# %% [markdown]
# What is the number of items placed for the 8th person on this list? Enter that number below.

# %% [markdown]
# 7

# %% [markdown]
# Find the albums with 12 or more tracks

# %%
tracks
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
tracks.groupby("Name").count()
# Out:
#                                                     TrackId  AlbumId  \
# Name
# "40"                                                      1        1
# "?"                                                       1        1
# "Eine Kleine Nachtmusik" Serenade In G, K. 525:...        1        1
# #1 Zero                                                   1        1
# #9 Dream                                                  1        1
# ...                                                     ...      ...
# É que Nessa Encarnação Eu Nasci Manga                     1        1
# Étude 1, In C Major - Preludio (Presto) - Liszt           1        1
# Óculos                                                    1        1
# Óia Eu Aqui De Novo                                       1        1
# Último Pau-De-Arara                                       1        1
#
#                                                     MediaTypeId  GenreId  \
# Name
# ...

# %%
tracks_df = pd.DataFrame(tracks.groupby("AlbumId")["TrackId"].count())

# %%
tracks_df
# Out:
#          TrackId
# AlbumId
# 1             10
# 2              1
# 3              3
# 4              8
# 5             15
# ...          ...
# 343            1
# 344            1
# 345            1
# 346            1
# 347            1
#
# [347 rows x 1 columns]

# %%
tracks_df.sort_values(by="TrackId", ascending=False)
# Out:
#          TrackId
# AlbumId
# 141           57
# 23            34
# 73            30
# 229           26
# 251           25
# ...          ...
# 289            1
# 288            1
# 287            1
# 286            1
# 347            1
#
# [347 rows x 1 columns]

# %%
tracks_df[tracks_df["TrackId"]>=12]
# Out:
#          TrackId
# AlbumId
# 5             15
# 6             13
# 7             12
# 8             14
# 10            14
# ...          ...
# 259           17
# 261           17
# 270           14
# 271           14
# 321           12
#
# [158 rows x 1 columns]

# %% [markdown]
# While the number of records returned is limited to 10, the query, if run correctly, will indicate how many total records there are. Enter that number below.

# %% [markdown]
# 158
